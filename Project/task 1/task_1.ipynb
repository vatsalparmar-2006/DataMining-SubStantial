# %%
import pandas as pd

# %%
df = pd.read_csv("./OnlineRetail.csv", encoding='latin1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# bydefault return first 5 rows
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
# bydefault return last 5 rows
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
# datatypes of each columns
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.describe()

# Note : df.describe = df.info
# Note : df.describe() != df.info()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.describe(include='all') # summarize all the col
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %%
df.shape # return tuple
# Out:
# (541909, 8)

# %%
print(f"Rows : {df.shape[0]}")
print(f"Cols : {df.shape[1]}")
# Out:
# Rows : 541909
# Cols : 8

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=541909, step=1)

# %%
# count of unique Description
df['Description'].nunique()
# Out:
# 4223

# %%
# name of unique Description
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], shape=(4224,), dtype=object)

# %%
df['Description'].value_counts() # most frequent Description
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# ANT SILVER TURQUOISE BOUDICCA RING       1
# Damages                                  1
# Found by jackie                          1
# water damaged                            1
# lost in space                            1
# Name: count, Length: 4223, dtype: int64

# %%
df.describe(include='all') # summarize all the col
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %%
df.iloc[10: 20] # Select rows 10 through 20 (rows- n to n-1)
# Out:
#    InvoiceNo StockCode                         Description  Quantity  \
# 10    536367     22745          POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748           POPPY'S PLAYHOUSE KITCHEN         6
# 12    536367     22749   FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13    536367     22310             IVORY KNITTED MUG COSY          6
# 14    536367     84969  BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15    536367     22623       BOX OF VINTAGE JIGSAW BLOCKS          3
# 16    536367     22622      BOX OF VINTAGE ALPHABET BLOCKS         2
# 17    536367     21754            HOME BUILDING BLOCK WORD         3
# 18    536367     21755            LOVE BUILDING BLOCK WORD         3
# 19    536367     21777         RECIPE BOX WITH METAL HEART         4
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 10  12/1/2010 8:34       2.10     13047.0  United Kingdom
# 11  12/1/2010 8:34       2.10     13047.0  United Kingdom
# ...

# %%
# add new column
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
print(f"Sum : {df['Quantity'].sum()}")
print(f"Max : {df['Quantity'].max()}")
print(f"Avg : {df['Quantity'].mean()}")
print(f"Median : {df['Quantity'].median()}")
print(f"Mode : {df['Quantity'].mode()}")
# Out:
# Min : -80995
# Max : 80995
# Avg : 9.55224954743324
# Median : 3.0
# Mode : 0    1
# Name: Quantity, dtype: int64

# %%
df[(df['Quantity']>3)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541903    581587     23256          CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
# return all column data(value is : True or False (value is null then true otherwisw false))
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country  TotalPrice
# ...

# %%
# return all column name with non-null count
(~df.isnull()).sum()
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# TotalPrice     541909
# dtype: int64

# %%
df.cov(numeric_only=True) # covariance
# Out:
#                 Quantity    UnitPrice    CustomerID     TotalPrice
# Quantity    47559.391409   -26.058761 -1.534050e+03   73250.057621
# UnitPrice     -26.058761  9362.469164 -5.415793e+02   -5938.944146
# CustomerID  -1534.050176  -541.579276  2.936426e+06   -1666.298038
# TotalPrice  73250.057621 -5938.944146 -1.666298e+03  143497.640005

# %%
df.corr(numeric_only=True) # correlation
# Out:
#             Quantity  UnitPrice  CustomerID  TotalPrice
# Quantity    1.000000  -0.001235   -0.003600    0.886681
# UnitPrice  -0.001235   1.000000   -0.004560   -0.162029
# CustomerID -0.003600  -0.004560    1.000000   -0.002274
# TotalPrice  0.886681  -0.162029   -0.002274    1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,3))
plt.hist(df['UnitPrice'], bins=6)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(4, 3))
df[['Country', 'UnitPrice']].boxplot()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4, 3))
plt.scatter(df['Quantity'], df['TotalPrice'], alpha=0.5)
plt.title('Quantity vs TotalPrice')
plt.xlabel('Quantity')
plt.ylabel('TotalPrice')
plt.grid(True)
plt.show()
